# %% [markdown]
# ## Elmo Fixation Probability/Proportion Global Results (NO Tutorial)

# %%
import pandas as pd
import csv
from matplotlib import pyplot as plt

probability_o = 100*0.251981539888380	
probability_ox =  100*0.421285364448084
probability_o_sem = 100*0.105315241667585
probability_ox_sem = 100*0.149441891464196

positions = [0, 10]
labels = ['Without XAI', 'With XAI']
y_index = [0, 10]
    
plt.figure(figsize=(10, 6))
plt.errorbar(y_index, [probability_o, probability_ox], [probability_o_sem, probability_ox_sem], color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = '-', capsize=5, capthick=1, ecolor='black')

plt.ylabel('Probability of Elmo Fixation [%]')
plt.xlabel('Presence of XAI')
plt.xticks(positions, labels)
# plt.title('Elmo Fixation Count')
# plt.savefig('elmo_probability_fixation_means_plot.png', dpi = 1600, bbox_inches='tight')
plt.savefig('elmo_probability_fixation_means_plot.pdf', dpi = 600, bbox_inches='tight')
plt.show()

# %%
probability_o = 0.463346837515899	
probability_ox =  0.390507995284886
probability_o_sem = 0.133427860966786
probability_ox_sem = 0.106633782294084

positions = [0, 10]
labels = ['Without XAI', 'With XAI']
y_index = [0, 10]
    
plt.figure(figsize=(10, 6))
plt.errorbar(y_index, [probability_o, probability_ox], [probability_o_sem, probability_ox_sem], color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = '-', capsize=5, capthick=1, ecolor='black')

plt.ylabel('Proportion of Elmo Fixation')
plt.xlabel('Presence of XAI')
plt.xticks(positions, labels)
# plt.title('Elmo Fixation Count')
plt.savefig('elmo_proportion_fixation_means_plot.png', dpi = 1600, bbox_inches='tight')
plt.savefig('elmo_proportion_fixation_means_plot.pdf', dpi = 600, bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Elmo Fixation Probability/Proportion only Human-AI decision after XAI removed (No Tutorial)

# %%
import pandas as pd
import csv
from matplotlib import pyplot as plt

probability_o = 100*0.251981539888380
probability_ox =  100*0.398930816040354
probability_o_sem = 100*0.105315241667585
probability_ox_sem = 100*0.151284325025230

positions = [0, 10]
labels = ['Without XAI', 'With XAI']
y_index = [0, 10]
    
plt.figure(figsize=(10, 6))
plt.errorbar(y_index, [probability_o, probability_ox], [probability_o_sem, probability_ox_sem], color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = '-', capsize=5, capthick=1, ecolor='black')

plt.ylabel('Probability of Elmo Fixation [%]')
plt.xlabel('Presence of XAI')
plt.xticks(positions, labels)
# plt.title('Elmo Fixation Count')
# plt.savefig('elmo_probability_fixation_means_plot.png', dpi = 1600, bbox_inches='tight')
plt.savefig('elmo_probability_fixation_means_plot_xai_removed.pdf', dpi = 600, bbox_inches='tight')
plt.show()

# %%
probability_o = 0.463346837515899
probability_ox =  0.378273265761127
probability_o_sem = 0.133427860966786
probability_ox_sem = 0.084878554366443

positions = [0, 10]
labels = ['False', 'True']
y_index = [0, 10]
    
plt.figure(figsize=(10, 6))
plt.errorbar(y_index, [probability_o, probability_ox], [probability_o_sem, probability_ox_sem], color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = '-', capsize=5, capthick=1, ecolor='black')

plt.ylabel('Proportion of Elmo Fixation')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
# plt.title('Elmo Fixation Count')
plt.savefig('elmo_proportion_fixation_means_plot_xai_removed.pdf', dpi = 600, bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Elmo Fixation Probability/Proportion Global Results (NO Tutorial) By GROUPS

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# XAI = False
# Reliance

x_1 = 0.554992401699879*100 # X/Y
x_1_sem = 0.055544168801552*100

# Overreliance

x_2 = 0.709464809384164*100
x_2_sem = 0.169199748611734*100

# Underreliance

x_4 = 100*0.393840222802408
x_4_sem = 100*0.055518445864241


# Matching Decision

x_6 = 100*0.549260260814816
x_6_sem =  100*0.074313933715504


# XAI = True

# Reliance

x_0 = 100*0.621086550150763
x_0_sem =    0.114746690754152*100

# Overreliance

x_3 = 100*0.849380970336853
x_3_sem = 100*0.432903872555025

# Underreliance

x_5 = 100*0.437338878511468
x_5_sem = 0.116907057212158*100


# Matching Decisions


x_7 = 100*0.679130276691650
x_7_sem =  100*0.049167371071063


positions = [1.5, 9.5]
labels = ['Without XAI', 'With XAI']

y_index = [0.5, 8.5]
y_index_2 = [1, 9]
y_index_3 = [1.5, 9.5]
y_index_4 = [2, 10]

plt.figure(figsize=(10, 6))

# Reliance in XAI = False + True
plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Reliance')

# Overreliance in XAI = True and False
plt.errorbar(y_index_2, [x_2, x_3],\
              [x_2_sem, x_3_sem], \
             markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Overreliance')

# Underreliance in XAI = True and False
plt.errorbar(y_index_3, [x_4, x_5],\
              [x_4_sem, x_5_sem], \
             markeredgecolor = 'black', color='black', markerfacecolor = 'white', marker='s', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Underreliance')

# Matching Decision in XAI = True and False
plt.errorbar(y_index_4, [x_6, x_7],\
              [x_6_sem, x_7_sem], \
              markeredgecolor = 'black', color='black', marker = 'v', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Matching Decisions')


plt.legend()
plt.ylabel('Probability of Elmo Fixation [%]')
plt.xlabel('Presence of XAI')
plt.xticks(positions, labels)
plt.savefig('means_plot_reliance_groups_probability_fixation.pdf', dpi = 600, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


# SEM of ratio X/Y = sqrt((SEM_X/X)**2 + (SEM_Y/Y)**2)/Y
# XAI = False

import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# XAI = False
# Reliance

x_1 = 0.131798424964094 # X/Y
x_1_sem = 0.016221971749370

# Overreliance

x_2 = 0.074981380619222	
x_2_sem = 0.017763108908046

# Underreliance

x_4 = 0.108530886354038
x_4_sem = 0.027759242622292


# Matching Decision

x_6 = 0.167256089658243
x_6_sem =  0.022506368981868


# XAI = True

# Reliance

x_0 = 0.118087938619773
x_0_sem = 0.020594417945383

# Overreliance

x_3 = 0.178993569216781
x_3_sem = 0.074443023068779

# Underreliance

x_5 = 0.083330215827598
x_5_sem = 0.019321361306288


# Matching Decisions

x_7 = 0.132705531436651
x_7_sem =  0.009953062976778


positions = [1.5, 9.5]
labels = ['Without XAI', 'With XAI']

y_index = [0.5, 8.5]
y_index_2 = [1, 9]
y_index_3 = [1.5, 9.5]
y_index_4 = [2, 10]

plt.figure(figsize=(10, 6))

# Reliance in XAI = False + True
plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Reliance')

# Overreliance in XAI = True and False
plt.errorbar(y_index_2, [x_2, x_3],\
              [x_2_sem, x_3_sem], \
             markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Overreliance')

# Underreliance in XAI = True and False
plt.errorbar(y_index_3, [x_4, x_5],\
              [x_4_sem, x_5_sem], \
             markeredgecolor = 'black', color='black', markerfacecolor = 'white', marker='s', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Underreliance')

# Matching Decision in XAI = True and False
plt.errorbar(y_index_4, [x_6, x_7],\
              [x_6_sem, x_7_sem], \
              markeredgecolor = 'black', color='black', marker = 'v', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Matching Decisions')


plt.legend()
plt.ylabel('Proportion of Elmo Fixation')
plt.xlabel('Presence of XAI')
plt.xticks(positions, labels)
# plt.savefig('means_plot_reliance_groups_proportion_fixation.png', dpi = 1600, bbox_inches='tight')
plt.savefig('means_plot_reliance_groups_proportion_fixation.pdf', dpi = 600, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Elmo Fixation Probability/Proportion only Human-AI decision after XAI removed (No Tutorial) BY GROUPS

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# XAI = False
# Reliance

x_1 = 0.554992401699879*100 # X/Y
x_1_sem = 0.078699947647438*100

# Overreliance

x_2 = 0.709464809384164*100
x_2_sem = 0.241270377429327*100

# Underreliance

x_4 = 100*0.108530886354038
x_4_sem = 100*0.039545101956116


# Matching Decision

x_6 = 100*0.549260260814816
x_6_sem =  100*0.105231819298723


# XAI = True

# Reliance

x_0 = 100*0.757057611685949	
x_0_sem =    0.228603734247918*100

# Overreliance

x_3 = 100*0.966689560439560
x_3_sem = 100*0.635978967070351

# Underreliance

x_5 = 100*0.465628261856914
x_5_sem = 0.160204866195783*100


# Matching Decisions


x_7 = 100*0.549260260814816
x_7_sem =  100*0.105231819298723


positions = [1.5, 9.5]
labels = ['Without XAI', 'With XAI']

y_index = [0.5, 8.5]
y_index_2 = [1, 9]
y_index_3 = [1.5, 9.5]
y_index_4 = [2, 10]

plt.figure(figsize=(10, 6))

# Reliance in XAI = False + True
plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Reliance')

# Overreliance in XAI = True and False
plt.errorbar(y_index_2, [x_2, x_3],\
              [x_2_sem, x_3_sem], \
             markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Overreliance')

# Underreliance in XAI = True and False
plt.errorbar(y_index_3, [x_4, x_5],\
              [x_4_sem, x_5_sem], \
             markeredgecolor = 'black', color='black', markerfacecolor = 'white', marker='s', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Underreliance')

# Matching Decision in XAI = True and False
plt.errorbar(y_index_4, [x_6, x_7],\
              [x_6_sem, x_7_sem], \
              markeredgecolor = 'black', color='black', marker = 'v', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Matching Decisions')


plt.legend()
plt.ylabel('Probability of Elmo Fixation [%]')
plt.xlabel('Presence of XAI')
plt.xticks(positions, labels)
plt.savefig('means_plot_reliance_groups_probability_fixation_XAI_removed.pdf', dpi = 600, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


# SEM of ratio X/Y = sqrt((SEM_X/X)**2 + (SEM_Y/Y)**2)/Y
# XAI = False

import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# XAI = False
# Reliance

x_1 = 0.131798424964094 # X/Y
x_1_sem = 0.022984740882070

# Overreliance

x_2 = 0.074981380619222	
x_2_sem = 0.025329304716623

# Underreliance

x_4 = 0.108530886354038
x_4_sem = 0.039545101956116


# Matching Decision

x_6 = 0.167256089658243
x_6_sem =  0.031870014617141


# XAI = True

# Reliance

x_0 = 0.125157330790452
x_0_sem = 0.033965584148085

# Overreliance

x_3 = 0.195798570926816
x_3_sem = 0.117257279327103

# Underreliance

x_5 = 0.063035409906106	
x_5_sem = 0.020209742396414


# Matching Decisions

x_7 = 0.137621693139596
x_7_sem =  0.019515597923529


positions = [1.5, 9.5]
labels = ['Without XAI', 'With XAI']

y_index = [0.5, 8.5]
y_index_2 = [1, 9]
y_index_3 = [1.5, 9.5]
y_index_4 = [2, 10]

plt.figure(figsize=(10, 6))

# Reliance in XAI = False + True
plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Reliance')

# Overreliance in XAI = True and False
plt.errorbar(y_index_2, [x_2, x_3],\
              [x_2_sem, x_3_sem], \
             markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Overreliance')

# Underreliance in XAI = True and False
plt.errorbar(y_index_3, [x_4, x_5],\
              [x_4_sem, x_5_sem], \
             markeredgecolor = 'black', color='black', markerfacecolor = 'white', marker='s', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Underreliance')

# Matching Decision in XAI = True and False
plt.errorbar(y_index_4, [x_6, x_7],\
              [x_6_sem, x_7_sem], \
              markeredgecolor = 'black', color='black', marker = 'v', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Matching Decisions')


plt.legend()
plt.ylabel('Proportion of Elmo Fixation')
plt.xlabel('Presence of XAI')
plt.xticks(positions, labels)
# plt.savefig('means_plot_reliance_groups_proportion_fixation.png', dpi = 1600, bbox_inches='tight')
plt.savefig('means_plot_reliance_groups_proportion_fixation_XAI_removed.pdf', dpi = 600, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


# SEM of ratio X/Y = sqrt((SEM_X/X)**2 + (SEM_Y/Y)**2)/Y
# XAI = False

import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# XAI = False
# Reliance

x_1 = 1.60 # X/Y
x_1_sem = 0.22

# Overreliance

x_2 = 1.54
x_2_sem = 0.29

# Underreliance

x_4 = 1.19
x_4_sem = 0.19




# XAI = True

# Reliance

x_0 = 2.96
x_0_sem = 0.77

# Overreliance

x_3 = 3.67
x_3_sem = 2.67

# Underreliance

x_5 = 3.07
x_5_sem = 1.52


positions = [1.5, 9.5]
# font size
# font size
plt.rcParams.update({'font.size': 20})
labels = ['Without XAI', 'With XAI']

y_index = [0.5, 8.5]
y_index_2 = [1, 9]
y_index_3 = [1.5, 9.5]
y_index_4 = [2, 10]

plt.figure(figsize=(10, 6))

# Reliance in XAI = False + True
plt.errorbar(y_index_2, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Reliance')

# Overreliance in XAI = True and False
plt.errorbar(y_index_3, [x_2, x_3],\
              [x_2_sem, x_3_sem], \
             markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Overreliance')

# Underreliance in XAI = True and False
plt.errorbar(y_index_4, [x_4, x_5],\
              [x_4_sem, x_5_sem], \
             markeredgecolor = 'black', color='black', markerfacecolor = 'white', marker='s', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Underreliance')

plt.legend()
plt.ylabel('Elmo Fixation Count')
plt.xlabel('Presence of XAI')
plt.xticks(positions, labels)
# plt.savefig('means_plot_reliance_groups_proportion_fixation.png', dpi = 1600, bbox_inches='tight')
plt.savefig('means_plot_reliance_groups_elmo_fixation_count.pdf', dpi = 600, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


# SEM of ratio X/Y = sqrt((SEM_X/X)**2 + (SEM_Y/Y)**2)/Y
# XAI = False

import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# XAI = False
# Reliance

x_1 = 0.11 # X/Y
x_1_sem = 0.03

# Overreliance

x_2 = 0.08
x_2_sem = 0.05

# Underreliance

x_4 = 0.016
x_4_sem = 0.01




# XAI = True

# Reliance

x_0 = 0.08
x_0_sem = 0.03

# Overreliance

x_3 = 0.14
x_3_sem = 0.14

# Underreliance

x_5 = 0.06
x_5_sem = 0.03


positions = [1.5, 9.5]
# font size
plt.rcParams.update({'font.size': 20})
labels = ['Without XAI', 'With XAI']

y_index = [0.5, 8.5]
y_index_2 = [1, 9]
y_index_3 = [1.5, 9.5]
y_index_4 = [2, 10]

plt.figure(figsize=(10, 6))

# Reliance in XAI = False + True
plt.errorbar(y_index_2, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Reliance')

# Overreliance in XAI = True and False
plt.errorbar(y_index_3, [x_2, x_3],\
              [x_2_sem, x_3_sem], \
             markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Overreliance')

# Underreliance in XAI = True and False
plt.errorbar(y_index_4, [x_4, x_5],\
              [x_4_sem, x_5_sem], \
             markeredgecolor = 'black', color='black', markerfacecolor = 'white', marker='s', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Underreliance')

plt.legend()
plt.ylabel('Elmo Mean Fixation Duration [s]')
plt.xlabel('Presence of XAI')
plt.xticks(positions, labels)
# plt.savefig('means_plot_reliance_groups_proportion_fixation.png', dpi = 1600, bbox_inches='tight')
plt.savefig('means_plot_reliance_groups_elmo_fixation_duration.pdf', dpi = 600, bbox_inches='tight')
plt.show()
