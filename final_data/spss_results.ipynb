# %% [markdown]
# ### Mean and SEM plots of statistical results from SPSS

# %%
import pandas as pd
import csv
from matplotlib import pyplot as plt

def get_XAI(idd):
    if 'X' in idd:
        return 1
    else:
        return 0

def get_spss_data(tracker_results):
    tracker_results['XAI_value'] = tracker_results['ID'].apply(get_XAI)
    tracker_results['elmo_fixation_rate'] = tracker_results['x']/tracker_results['game_time']
    tracker_results['computer_fixation_rate'] = tracker_results['computer_fixation_count']/tracker_results['game_time']

    tracker_results['elmo_fixation_percentage'] = tracker_results['elmo_total_fixation_duration']/(tracker_results['elmo_total_fixation_duration']+tracker_results['computer_total_fixation_duration'])
    tracker_results['computer_fixation_percentage'] = tracker_results['computer_total_fixation_duration']/(tracker_results['elmo_total_fixation_duration']+tracker_results['computer_total_fixation_duration'])

    tracker_results['elmo_probability_fixation'] = tracker_results['x']/(tracker_results['x']+tracker_results['computer_fixation_count'])
    tracker_results['computer_probability_fixation'] = tracker_results['computer_fixation_count']/(tracker_results['x']+tracker_results['computer_fixation_count'])
    
    tracker_results['elmo_probability_to_computer'] = tracker_results['x']/tracker_results['computer_fixation_count']
    tracker_results['elmo_proportion_to_computer'] = tracker_results['elmo_total_fixation_duration']/tracker_results['computer_total_fixation_duration']

    
    tracker_results.to_csv('mushroom_data/tracker_results_final_XAI_numeric.csv', index=False)

tracker_results = pd.read_csv('mushroom_data/tracker_results_final_XAI_numeric.csv')
# get_spss_data(tracker_results)

elmo_count_o = 127.64
elmo_count_ox = 315
elmo_count_sem = 38.455
elmo_count_ox_sem = 38.455

computer_count_o = 399.43
computer_count_ox =  539
computer_count_sem =  36.509
computer_count_ox_sem = 60.024

positions = [0, 10]
labels = ['False', 'True']
y_index = [0, 10]
    
plt.figure(figsize=(10, 6))
plt.errorbar(y_index, [elmo_count_o, elmo_count_ox], [elmo_count_sem, elmo_count_ox_sem], color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = '-', capsize=5, capthick=1, ecolor='black')
plt.errorbar(y_index, [computer_count_o, computer_count_ox], [computer_count_sem, computer_count_ox_sem], markeredgecolor = 'black', color='black', marker = 'o', ls = '--', capsize=5, capthick=1, ecolor='black')

# plt.plot(y_index, [elmo_count_o, elmo_count_ox], color='tab:blue', linestyle = '-')
# plt.plot(y_index, [computer_count_o, computer_count_ox], color='tab:orange', linestyle = '-')
handles = [
        plt.Line2D([], [], color='black', linestyle='-', label='Robot Elmo'),
        plt.Line2D([], [], color='black', linestyle='--', label='Computer'),
    ]
plt.legend(handles=handles)

plt.ylabel('Total Fixation Count')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
# plt.title('Elmo Fixation Count')
plt.savefig('fixation_count_means_plot.png', dpi = 1600, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Game Time

# %%
game_time_o = 702.6620889
game_time_ox =  886.60823
game_time_o_sem = 55.8033
game_time_ox_sem = 58.51719

positions = [0, 10]
labels = ['False', 'True']
y_index = [0, 10]
    
plt.figure(figsize=(10, 6))
plt.errorbar(y_index, [game_time_o, game_time_ox], [game_time_o_sem, game_time_ox_sem], color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = '-', capsize=5, capthick=1, ecolor='black')

plt.ylabel('Task Duration [s]')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
# plt.title('Elmo Fixation Count')
plt.savefig('task_duration_means_plot.png', dpi = 1600, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Total Fixation Duration

# %%
elmo_count_o = 62.08548
elmo_count_ox = 120.17488
elmo_count_sem = 19.600326
elmo_count_ox_sem = 30.54468

computer_count_o = 488.8677
computer_count_ox =  712.0265837
computer_count_sem =  48.186756
computer_count_ox_sem = 54.40068

positions = [0, 10]
labels = ['False', 'True']
y_index = [0, 10]
    
plt.figure(figsize=(10, 6))
plt.errorbar(y_index, [elmo_count_o, elmo_count_ox], [elmo_count_sem, elmo_count_ox_sem], color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = '-', capsize=5, capthick=1, ecolor='black')
# plt.errorbar(y_index, [computer_count_o, computer_count_ox], [computer_count_sem, computer_count_ox_sem], markeredgecolor = 'black', color='black', marker = 'o', ls = '--', capsize=5, capthick=1, ecolor='black')

# plt.plot(y_index, [elmo_count_o, elmo_count_ox], color='tab:blue', linestyle = '-')
# plt.plot(y_index, [computer_count_o, computer_count_ox], color='tab:orange', linestyle = '-')
handles = [
        plt.Line2D([], [], color='black', linestyle='-', label='Robot Elmo'),
        # plt.Line2D([], [], color='black', linestyle='--', label='Computer'),
    ]
plt.legend(handles=handles)

plt.ylabel('Total Fixation Duration [s]')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
# plt.title('Elmo Fixation Count')
plt.savefig('elmo_fixation_duration_means_plot.png', dpi = 1600, bbox_inches='tight')
plt.show()

# %%
elmo_count_o = 62.08548
elmo_count_ox = 120.17488
elmo_count_sem = 19.600326
elmo_count_ox_sem = 30.54468

computer_count_o = 488.8677
computer_count_ox =  712.0265837
computer_count_sem =  48.186756
computer_count_ox_sem = 54.40068

positions = [0, 10]
labels = ['False', 'True']
y_index = [0, 10]
    
plt.figure(figsize=(10, 6))
plt.errorbar(y_index, [computer_count_o, computer_count_ox], [computer_count_sem, computer_count_ox_sem], color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = '-', capsize=5, capthick=1, ecolor='black')
# plt.errorbar(y_index, [computer_count_o, computer_count_ox], [computer_count_sem, computer_count_ox_sem], markeredgecolor = 'black', color='black', marker = 'o', ls = '--', capsize=5, capthick=1, ecolor='black')

# plt.plot(y_index, [elmo_count_o, elmo_count_ox], color='tab:blue', linestyle = '-')
# plt.plot(y_index, [computer_count_o, computer_count_ox], color='tab:orange', linestyle = '-')
handles = [
        # plt.Line2D([], [], color='black', linestyle='-', label='Robot Elmo'),
        plt.Line2D([], [], color='black', linestyle='--', label='Computer'),
    ]
plt.legend(handles=handles)

plt.ylabel('Total Fixation Duration [s]')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
# plt.title('Elmo Fixation Count')
plt.savefig('computer_fixation_duration_means_plot.png', dpi = 1600, bbox_inches='tight')
plt.show()

# %%
probability_o = 100*0.30774980
probability_ox =  100*0.604574
probability_o_sem = 100*0.093505
probability_ox_sem = 100*0.16088971

positions = [0, 10]
labels = ['False', 'True']
y_index = [0, 10]
    
plt.figure(figsize=(10, 6))
plt.errorbar(y_index, [probability_o, probability_ox], [probability_o_sem, probability_ox_sem], color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = '-', capsize=5, capthick=1, ecolor='black')

plt.ylabel('Probability of Elmo Fixation [%]')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
# plt.title('Elmo Fixation Count')
plt.savefig('elmo_probability_fixation_means_plot.png', dpi = 1600, bbox_inches='tight')
plt.savefig('mushroom_results/elmo_probability_fixation_means_plot.pdf', dpi = 600, bbox_inches='tight')
plt.show()

# %%
probability_o = 0.12601
probability_ox =  0.162785
probability_o_sem = 0.039919
probability_ox_sem = 0.0370265

positions = [0, 10]
labels = ['False', 'True']
y_index = [0, 10]
    
plt.figure(figsize=(10, 6))
plt.errorbar(y_index, [probability_o, probability_ox], [probability_o_sem, probability_ox_sem], color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = '-', capsize=5, capthick=1, ecolor='black')

plt.ylabel('Proportion of Elmo Fixation')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
# plt.title('Elmo Fixation Count')
plt.savefig('elmo_proportion_fixation_means_plot.png', dpi = 1600, bbox_inches='tight')
plt.savefig('mushroom_results/elmo_proportion_fixation_means_plot.pdf', dpi = 600, bbox_inches='tight')

plt.show()

# %%
elmo_average_duration_o = 0.467277
elmo_average_duration_ox =  0.42615755
computer_average_duration_o = 1.27908
computer_average_duration_ox = 1.4114
elmo_average_duration_o_sem = 0.07046
elmo_average_duration_ox_sem = 0.03327
computer_average_duration_o_sem = 0.1217019
computer_average_duration_ox_sem = 0.118808

positions = [0, 10]
labels = ['False', 'True']
y_index = [0, 10]
    
plt.figure(figsize=(10, 6))
plt.errorbar(y_index, [elmo_average_duration_o, elmo_average_duration_ox], [elmo_average_duration_o_sem, elmo_average_duration_ox_sem], color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = '-', capsize=5, capthick=1, ecolor='black')
plt.errorbar(y_index, [computer_average_duration_o, computer_average_duration_ox], [computer_average_duration_o_sem, computer_average_duration_ox_sem], markeredgecolor = 'black', color='black', marker = 'o', ls = '--', capsize=5, capthick=1, ecolor='black')

# plt.plot(y_index, [elmo_count_o, elmo_count_ox], color='tab:blue', linestyle = '-')
# plt.plot(y_index, [computer_count_o, computer_count_ox], color='tab:orange', linestyle = '-')
handles = [
        plt.Line2D([], [], color='black', linestyle='-', label='Robot Elmo'),
        plt.Line2D([], [], color='black', linestyle='--', label='Computer'),
    ]
plt.legend(handles=handles)

plt.ylabel('Avg. Fixation Duration [s]')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
# plt.title('Elmo Fixation Count')
plt.savefig('average_fixation_means_plot.png', dpi = 1600, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### ELMO FIXATION COUNT BY RELIANCE GROUPS

# %%
import pandas as pd
from matplotlib import pyplot as plt

# XAI = True, Reliance and No Reliance
x_1 = 8.85
x_1_sem = 2.83
x_10 = 8.17
x_10_sem = 3.088

# XAI = False, Reliance and No Reliance
x_0 = 4.82
x_0_sem = 1.053

x_11 = 3.43
x_11_sem = 1.639


positions = [1, 9]
labels = ['True', 'False']
y_index = [0.5, 8.5]
y_index_2 = [1.5, 9.5]

plt.figure(figsize=(10, 6))

plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Reliance')
plt.errorbar(y_index_2, [x_10, x_11],\
              [x_10_sem, x_11_sem], \
              markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'No Reliance')

plt.legend()
plt.ylabel('Elmo Avg. Fixation Count')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
plt.savefig('reliance_images/means_plot_reliance_elmo_fixation.png', dpi = 1600, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Elmo fixation duration by Reliance

# %%
import pandas as pd
from matplotlib import pyplot as plt

# XAI = True, Reliance and No Reliance
x_1 = 0.120998
x_1_sem = 0.041411
x_10 = 0.09844
x_10_sem = 0.041085

# XAI = False, Reliance and No Reliance
x_0 = 0.143867
x_0_sem = 0.0364859

x_11 = 0.06639
x_11_sem = 0.026639


positions = [1, 9]
labels = ['True', 'False']
y_index = [0.5, 8.5]
y_index_2 = [1.5, 9.5]

plt.figure(figsize=(10, 6))

plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Reliance')
plt.errorbar(y_index_2, [x_10, x_11],\
              [x_10_sem, x_11_sem], \
              markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'No Reliance')

plt.legend()
plt.ylabel('Elmo Avg. Fixation Duration [s]')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
plt.savefig('reliance_images/means_plot_reliance_elmo_duration.png', dpi = 1600, bbox_inches='tight')
plt.show()

# Big differences in elmo fixation duration between reliance and no reliance for XAI = False. 
# When people rely on the AI agent without explanation, they fixate on Elmo for a longer time.

# %% [markdown]
# ### Computer Count By Reliance

# %%
import pandas as pd
from matplotlib import pyplot as plt

# XAI = True, Reliance and No Reliance
x_1 = 26.88 
x_1_sem = 2.488
x_10 = 35.27
x_10_sem = 3.533

# XAI = False, Reliance and No Reliance
x_0 = 20.21 
x_0_sem = 1.845

x_11 = 15.83 
x_11_sem = 2.039


positions = [1, 9]
labels = ['True', 'False']
y_index = [0.5, 8.5]
y_index_2 = [1.5, 9.5]

plt.figure(figsize=(10, 6))

plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Reliance')
plt.errorbar(y_index_2, [x_10, x_11],\
              [x_10_sem, x_11_sem], \
              markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'No Reliance')

plt.legend()
plt.ylabel('Computer Avg. Fixation Count')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
plt.savefig('reliance_images/means_plot_reliance_computer_count.png', dpi = 1600, bbox_inches='tight')
plt.show()

# The high computer fixation counts in XAI = True correlate with the high 
# Elmo fixation counts.

# %% [markdown]
# ### Computer Fixation Duration (Reliance and No Reliance)

# %%
import pandas as pd
from matplotlib import pyplot as plt

# XAI = True, Reliance and No Reliance
x_1 = 1.37506 
x_1_sem = 0.139161
x_10 = 1.22982
x_10_sem = 0.089525

# XAI = False, Reliance and No Reliance
x_0 = 1.2757
x_0_sem = 0.085133

x_11 = 1.34737
x_11_sem = 0.2065808


positions = [1, 9]
labels = ['True', 'False']
y_index = [0.5, 8.5]
y_index_2 = [1.5, 9.5]

plt.figure(figsize=(10, 6))

plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Reliance')
plt.errorbar(y_index_2, [x_10, x_11],\
              [x_10_sem, x_11_sem], \
              markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'No Reliance')

plt.legend()
plt.ylabel('Computer Avg. Fixation Duration [s]')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
plt.savefig('reliance_images/means_plot_reliance_computer_duration.png', dpi = 1600, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Fixation Count Elmo (Overreliance)

# %%
import pandas as pd
from matplotlib import pyplot as plt

# XAI = True, OverReliance
x_1 = 3.80
x_1_sem =  2.905
x_10 = 5.07 
x_10_sem = 2.428

# XAI = False, Reliance and No Reliance
x_0 = 4.19 
x_0_sem =  2.157

x_11 = 4.25
x_11_sem = 5.679

positions = [1, 9]
labels = ['True', 'False']
y_index = [0.5, 8.5]
y_index_2 = [1.5, 9.5]

plt.figure(figsize=(10, 6))

plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Overreliance')
plt.errorbar(y_index_2, [x_10, x_11],\
              [x_10_sem, x_11_sem], \
              markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'No Overreliance')

plt.legend()
plt.ylabel('Elmo Avg. Fixation Count')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
plt.savefig('reliance_images/means_plot_overreliance_elmo_count.png', dpi = 1600, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Duration Elmo (Overreliance)

# %%
import pandas as pd
from matplotlib import pyplot as plt

# XAI = True, OverReliance
x_1 = 0.0355
x_1_sem =   0.031723
x_10 = 0.0927 
x_10_sem = 0.053627

# XAI = False, Reliance and No Reliance
x_0 = 0.1723205
x_0_sem =  0.08969

x_11 = 0.1601567
x_11_sem = 0.11921

positions = [1, 9]
labels = ['True', 'False']
y_index = [0.5, 8.5]
y_index_2 = [1.5, 9.5]

plt.figure(figsize=(10, 6))

plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Overreliance')
plt.errorbar(y_index_2, [x_10, x_11],\
              [x_10_sem, x_11_sem], \
              markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'No Overreliance')

plt.legend()
plt.ylabel('Elmo Avg. Fixation Duration [s]')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
plt.savefig('reliance_images/means_plot_overreliance_elmo_duration.png', dpi = 1600, bbox_inches='tight')
plt.show()

# Regardless of relying on the AI agent, people fixate on Elmo for a longer time when the AI agent is not explainable.
# This is interesting because it shows that people are more likely to fixate on Elmo when the AI agent is not explainable.

# %% [markdown]
# ### Computer Fixation Count (Overreliance)

# %%
import pandas as pd
from matplotlib import pyplot as plt

# XAI = True, OverReliance
x_1 = 16.20
x_1_sem =   6.902
x_10 = 33.86 
x_10_sem = 5.575

# XAI = False, Reliance and No Reliance
x_0 = 18.44
x_0_sem =  3.384

x_11 = 13.25
x_11_sem = 5.764

positions = [1, 9]
labels = ['True', 'False']
y_index = [0.5, 8.5]
y_index_2 = [1.5, 9.5]

plt.figure(figsize=(10, 6))

plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Overreliance')
plt.errorbar(y_index_2, [x_10, x_11],\
              [x_10_sem, x_11_sem], \
              markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'No Overreliance')

plt.legend()
plt.ylabel('Computer Avg. Fixation Count')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
plt.savefig('reliance_images/means_plot_overreliance_computer_count.png', dpi = 1600, bbox_inches='tight')
plt.show()

# Users that don't rely on the AI agent fixate more on the computer, when there is an explanation.

# %% [markdown]
# ### Computer Fixation Duration (Overreliance)

# %%
import pandas as pd
from matplotlib import pyplot as plt

# XAI = True, OverReliance
x_1 = 0.862001
x_1_sem =   0.38404
x_10 =1.14296477
x_10_sem = 0.117259
# XAI = False, Reliance and No Reliance
x_0 = 1.4375135908
x_0_sem =  0.186041

x_11 = 1.027777
x_11_sem = 0.355007

positions = [1, 9]
labels = ['True', 'False']
y_index = [0.5, 8.5]
y_index_2 = [1.5, 9.5]

plt.figure(figsize=(10, 6))

plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Overreliance')
plt.errorbar(y_index_2, [x_10, x_11],\
              [x_10_sem, x_11_sem], \
              markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'No Overreliance')

plt.legend()
plt.ylabel('Computer Avg. Fixation Duration [s]')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
plt.savefig('reliance_images/means_plot_overreliance_computer_duration.png', dpi = 1600, bbox_inches='tight')
plt.show()

# Not significant

# %% [markdown]
# ### Elmo Fixation Count (Underreliance)

# %%
import pandas as pd
from matplotlib import pyplot as plt

# XAI = True, OverReliance
x_1 = 10.88
x_1_sem =   5.390
x_10 = 9.72
x_10_sem = 3.267
# XAI = False, Reliance and No Reliance
x_0 = 3.26
x_0_sem =  1.919

x_11 = 5
x_11_sem = 1.214

positions = [1, 9]
labels = ['True', 'False']
y_index = [0.5, 8.5]
y_index_2 = [1.5, 9.5]

plt.figure(figsize=(10, 6))

plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Underreliance')
plt.errorbar(y_index_2, [x_10, x_11],\
              [x_10_sem, x_11_sem], \
              markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'No Underreliance')

plt.legend()
plt.ylabel('Elmo Avg. Fixation Count')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
plt.savefig('reliance_images/means_plot_underrreliance_elmo_count.png', dpi = 1600, bbox_inches='tight')
plt.show()

# Not significant

# %% [markdown]
# ### Fixation Duration Elmo (Overreliance)

# %%
import pandas as pd
from matplotlib import pyplot as plt

# XAI = True, OverReliance
x_1 = 0.1034436
x_1_sem =   0.062727
x_10 = 0.13573
x_10_sem =  0.0478
# XAI = False, Reliance and No Reliance
x_0 = 0.04665
x_0_sem =  0.0206599

x_11 = 0.13577
x_11_sem = 0.0397559

positions = [1, 9]
labels = ['True', 'False']
y_index = [0.5, 8.5]
y_index_2 = [1.5, 9.5]

plt.figure(figsize=(10, 6))

plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Underreliance')
plt.errorbar(y_index_2, [x_10, x_11],\
              [x_10_sem, x_11_sem], \
              markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'No Underreliance')

plt.legend()
plt.ylabel('Elmo Avg. Fixation Duration [s]')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
plt.savefig('reliance_images/means_plot_underrreliance_elmo_duration.png', dpi = 1600, bbox_inches='tight')
plt.show()

# Not significant. Lowest in XAI = False, No Underreliance

# %% [markdown]
# ### Computer Fixation Count Underreliance

# %%
import pandas as pd
from matplotlib import pyplot as plt

# XAI = True, OverReliance
x_1 = 36.50
x_1_sem = 4.634
x_10 = 28.72
x_10_sem =  2.560
# XAI = False, Reliance and No Reliance
x_0 = 16.37
x_0_sem =  2.211

x_11 = 20.70
x_11_sem = 2.173

positions = [1, 9]
labels = ['True', 'False']
y_index = [0.5, 8.5]
y_index_2 = [1.5, 9.5]

plt.figure(figsize=(10, 6))

plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Underreliance')
plt.errorbar(y_index_2, [x_10, x_11],\
              [x_10_sem, x_11_sem], \
              markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'No Underreliance')

plt.legend()
plt.ylabel('Computer Avg. Fixation Count')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
plt.savefig('reliance_images/means_plot_underrreliance_computer_count.png', dpi = 1600, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Computer Fixation Duration (Underreliance)

# %%
import pandas as pd
from matplotlib import pyplot as plt

# XAI = True, OverReliance
x_1 = 1.3058 
x_1_sem =  0.1334
x_10 = 1.4635
x_10_sem =  0.14569

# XAI = False, Reliance and No Reliance
x_0 = 1.41466 
x_0_sem =  0.23931

x_11 = 1.2303
x_11_sem = 0.09558

positions = [1, 9]
labels = ['True', 'False']
y_index = [0.5, 8.5]
y_index_2 = [1.5, 9.5]

plt.figure(figsize=(10, 6))

plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Underreliance')
plt.errorbar(y_index_2, [x_10, x_11],\
              [x_10_sem, x_11_sem], \
              markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'No Underreliance')

plt.legend()
plt.ylabel('Computer Avg. Fixation Duration [s]')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
plt.savefig('reliance_images/means_plot_underrreliance_computer_duration.png', dpi = 1600, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Reliance, Overreliance and No Underreliance Means Plot Elmo Fixation Count

# %%
import pandas as pd
from matplotlib import pyplot as plt

# XAI = False

# Reliance

x_1 = 4.82
x_1_sem = 1.053

# Overreliance

x_2 = 4.19
x_2_sem = 2.157


# No Underreliance

x_6 = 5
x_6_sem = 1.214

# Underreliance

x_4 = 3.26
x_4_sem = 1.919

# XAI = True

# Reliance

x_0 = 8.85
x_0_sem =   2.83

# Overreliance

x_3 = 3.80
x_3_sem =  2.905

# No Underreliance

x_7 = 9.72
x_7_sem = 3.267

# Underreliance

x_5 = 10.88
x_5_sem = 5.390


positions = [1.5, 9.5]
labels = ['False', 'True']

y_index = [0.5, 8.5]
y_index_2 = [1, 9]
y_index_3 = [1.5, 9.5]
y_index_4 = [2, 10]

plt.figure(figsize=(10, 6))

# Reliance in XAI = False + True
plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Reliance')

# Overreliance in XAI = True and False
plt.errorbar(y_index_2, [x_2, x_3],\
              [x_2_sem, x_3_sem], \
             markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Overreliance')

# Underreliance in XAI = True and False
plt.errorbar(y_index_3, [x_4, x_5],\
              [x_4_sem, x_5_sem], \
             markeredgecolor = 'black', color='black', markerfacecolor = 'white', marker='s', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Underreliance')

# No Underreliance in XAI = True and False
# plt.errorbar(y_index_4, [x_6, x_7],\
#               [x_6_sem, x_7_sem], \
#              markeredgecolor = 'black', color='black', marker = 'v', ls='none', capsize=5, capthick=1, ecolor='black', label = 'No Underreliance')

plt.legend()
plt.ylabel('Elmo Avg. Fixation Count')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
plt.savefig('reliance_images/means_plot_reliance_groups_elmo_count.png', dpi = 1600, bbox_inches='tight')
plt.show()

# Not significant

# %% [markdown]
# ### Elmo Fixation Duration All RELIACNE GROUPS

# %%
import pandas as pd
from matplotlib import pyplot as plt

# XAI = False

# Reliance

x_1 = 0.143867 
x_1_sem = 0.0364859

# Overreliance

x_2 = 0.1723205
x_2_sem = 0.08969


# Underreliance

x_4 = 0.04665
x_4_sem = 0.0206599

# No Underreliance

x_6 = 0.13577
x_6_sem = 0.0397559

# XAI = True

# Reliance

x_0 = 0.120998
x_0_sem =    0.041411

# Overreliance

x_3 = 0.0355
x_3_sem =   0.031723

# Underreliance

x_5 = 0.1034436
x_5_sem = 0.062727


# No Underreliance

x_7 = 0.13573
x_7_sem = 0.0478



positions = [1.5, 9.5]
labels = ['False', 'True']

y_index = [0.5, 8.5]
y_index_2 = [1, 9]
y_index_3 = [1.5, 9.5]
y_index_4 = [2, 10]

plt.figure(figsize=(10, 6))

# Reliance in XAI = False + True
plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Reliance')

# Overreliance in XAI = True and False
plt.errorbar(y_index_2, [x_2, x_3],\
              [x_2_sem, x_3_sem], \
             markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Overreliance')

# Underreliance in XAI = True and False
plt.errorbar(y_index_3, [x_4, x_5],\
              [x_4_sem, x_5_sem], \
             markeredgecolor = 'black', color='black', markerfacecolor = 'white', marker='s', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Underreliance')

# No Underreliance in XAI = True and False
# plt.errorbar(y_index_4, [x_6, x_7],\
#               [x_6_sem, x_7_sem], \
#              markeredgecolor = 'black', color='black', marker = 'v', ls='none', capsize=5, capthick=1, ecolor='black', label = 'No Underreliance')


plt.legend()
plt.ylabel('Elmo Avg. Fixation Duration [s]')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
plt.savefig('reliance_images/means_plot_reliance_groups_elmo_duration.png', dpi = 1600, bbox_inches='tight')
plt.show()

# Not significant

# %% [markdown]
# ### Computer Fixation Duration All groups

# %%
import pandas as pd
from matplotlib import pyplot as plt

# XAI = False

# Reliance

x_1 = 1.2757  
x_1_sem = 0.085133

# Overreliance

x_2 = 1.4375135908
x_2_sem = 0.186041


# Underreliance

x_4 = 1.41466
x_4_sem =  0.23931

# No Underreliance

x_6 = 1.2303
x_6_sem =  0.09558

# XAI = True

# Reliance

x_0 = 1.37506
x_0_sem =    0.139161

# Overreliance

x_3 = 0.862001
x_3_sem =   0.38404

# Underreliance

x_5 = 1.3058
x_5_sem = 0.1334


# No Underreliance

x_7 = 1.4635
x_7_sem = 0.14569



positions = [1.5, 9.5]
labels = ['False', 'True']

y_index = [0.5, 8.5]
y_index_2 = [1, 9]
y_index_3 = [1.5, 9.5]
y_index_4 = [2, 10]

plt.figure(figsize=(10, 6))

# Reliance in XAI = False + True
plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Reliance')

# Overreliance in XAI = True and False
plt.errorbar(y_index_2, [x_2, x_3],\
              [x_2_sem, x_3_sem], \
             markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Overreliance')

# Underreliance in XAI = True and False
plt.errorbar(y_index_3, [x_4, x_5],\
              [x_4_sem, x_5_sem], \
             markeredgecolor = 'black', color='black', markerfacecolor = 'white', marker='s', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Underreliance')

# No Underreliance in XAI = True and False
# plt.errorbar(y_index_4, [x_6, x_7],\
#               [x_6_sem, x_7_sem], \
#              markeredgecolor = 'black', color='black', marker = 'v', ls='none', capsize=5, capthick=1, ecolor='black', label = 'No Underreliance')


plt.legend()
plt.ylabel('Computer Avg. Fixation Duration [s]')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
plt.savefig('reliance_images/means_plot_reliance_groups_computer_duration.png', dpi = 1600, bbox_inches='tight')
plt.show()

# Not significant

# %% [markdown]
# ### Computer Count Fixation ALL GROUPS

# %%
import pandas as pd
from matplotlib import pyplot as plt

# XAI = False

# Reliance

x_1 = 20.21
x_1_sem = 1.845

# Overreliance

x_2 = 18.44
x_2_sem = 3.384


# Underreliance

x_4 = 16.37
x_4_sem =  2.211

# No Underreliance

x_6 = 20.70 
x_6_sem =  2.173

# XAI = True

# Reliance

x_0 = 26.88
x_0_sem =    2.488

# Overreliance

x_3 = 16.20
x_3_sem = 6.902

# Underreliance

x_5 = 36.50 
x_5_sem = 4.634


# No Underreliance

x_7 = 28.72
x_7_sem = 2.560



positions = [1.5, 9.5]
labels = ['False', 'True']

y_index = [0.5, 8.5]
y_index_2 = [1, 9]
y_index_3 = [1.5, 9.5]
y_index_4 = [2, 10]

plt.figure(figsize=(10, 6))

# Reliance in XAI = False + True
plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Reliance')

# Overreliance in XAI = True and False
plt.errorbar(y_index_2, [x_2, x_3],\
              [x_2_sem, x_3_sem], \
             markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Overreliance')

# Underreliance in XAI = True and False
plt.errorbar(y_index_3, [x_4, x_5],\
              [x_4_sem, x_5_sem], \
             markeredgecolor = 'black', color='black', markerfacecolor = 'white', marker='s', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Underreliance')

# No Underreliance in XAI = True and False
# plt.errorbar(y_index_4, [x_6, x_7],\
#               [x_6_sem, x_7_sem], \
#              markeredgecolor = 'black', color='black', marker = 'v', ls='none', capsize=5, capthick=1, ecolor='black', label = 'No Underreliance')


plt.legend()
plt.ylabel('Computer Avg. Fixation Count')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
plt.savefig('reliance_images/means_plot_reliance_groups_computer_count.png', dpi = 1600, bbox_inches='tight')
plt.show()

# Not significant

# %% [markdown]
# ### Proportion of Elmo Fixation

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


# SEM of ratio X/Y = sqrt((SEM_X/X)**2 + (SEM_Y/Y)**2)/Y
# XAI = False

# Reliance

x_1 = 0.143867/1.2757  # X/Y
x_1_sem = 0.0364859/0.085133  # SEM_X/SEM_Y
x_1_sem = np.sqrt((0.0364859/0.143867)**2 + (0.085133/1.2757)**2)/1.2757
print(x_1_sem)

# Overreliance

x_2 = 0.1723205/1.4375135908 # X/Y
x_2_sem = 0.08969/0.186041 # SEM_X/SEM_Y
x_2_sem = np.sqrt((0.08969/0.1723205)**2 + (0.186041/1.4375135908)**2)/1.4375135908
print(x_2_sem)

# Underreliance

x_4 = 0.04665/1.41466
x_4_sem =  0.0206599/0.23931
x_4_sem = np.sqrt((0.0206599/0.04665)**2 + (0.23931/1.41466)**2)/1.41466

# No Underreliance

x_6 = 0.13577/1.2303
x_6_sem =  0.0397559/0.09558
x_6_sem = np.sqrt((0.0397559/0.13577)**2 + (0.09558/1.2303)**2)/1.2303


# XAI = True

# Reliance

x_0 = 0.120998/1.37506
x_0_sem = 0.041411/0.139161
x_0_sem = np.sqrt((0.041411/0.120998)**2 + (0.139161/1.37506)**2)/1.37506

# Overreliance

x_3 = 0.0355/0.862001
x_3_sem = 0.031723/0.38404
x_3_sem = np.sqrt((0.031723/0.0355)**2 + (0.38404/0.862001)**2)/0.862001


# Underreliance

x_5 = 0.1034436/1.3058
x_5_sem = 0.062727/0.1334
x_5_sem = np.sqrt((0.062727/0.1034436)**2 + (0.1334/1.3058)**2)/1.3058


# No Underreliance

x_7 = 0.13573/1.4635
x_7_sem = 0.0478/0.14569
x_7_sem = np.sqrt((0.0478/0.13573)**2 + (0.14569/1.4635)**2)/1.4635


positions = [1.5, 9.5]
labels = ['False', 'True']

y_index = [0.5, 8.5]
y_index_2 = [1, 9]
y_index_3 = [1.5, 9.5]
y_index_4 = [2, 10]

plt.figure(figsize=(10, 6))

# Reliance in XAI = False + True
plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Reliance')

# Overreliance in XAI = True and False
plt.errorbar(y_index_2, [x_2, x_3],\
              [x_2_sem, x_3_sem], \
             markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Overreliance')

# Underreliance in XAI = True and False
plt.errorbar(y_index_3, [x_4, x_5],\
              [x_4_sem, x_5_sem], \
             markeredgecolor = 'black', color='black', markerfacecolor = 'white', marker='s', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Underreliance')

# No Underreliance in XAI = True and False
# plt.errorbar(y_index_4, [x_6, x_7],\
#               [x_6_sem, x_7_sem], \
#              markeredgecolor = 'black', color='black', marker = 'v', ls='none', capsize=5, capthick=1, ecolor='black', label = 'No Underreliance')


plt.legend()
plt.ylabel('Proportion of Elmo Fixation')
plt.xlabel('XAI Model')
plt.xticks(positions, labels)
plt.savefig('reliance_images/means_plot_reliance_groups_proportion_fixation.png', dpi = 1600, bbox_inches='tight')
plt.savefig('reliance_images/means_plot_reliance_groups_proportion_fixation.pdf', dpi = 600, bbox_inches='tight')
plt.show()
# Out:
# 0.20556698717677793
# 0.37309723645841136

# %% [markdown]
# ### Probability of Elmo Fixation

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# XAI = False
# SEM of ratio X/Y = sqrt((SEM_X/X)**2 + (SEM_Y/Y)**2)/Y
# Reliance

x_1 = (4.82/20.21)*100 # X/Y
x_1_sem = 1.053/1.845 # SEM_X/SEM_Y
x_1_sem = (np.sqrt((1.053/4.82)**2+(1.845/20.21)**2)/20.21)*100

# Overreliance

x_2 = (4.19/18.44)*100
x_2_sem = 2.157/3.384
x_2_sem = (np.sqrt((2.157/4.19)**2+(3.384/18.44)**2)/18.44)*100
print(x_2_sem)

# Underreliance

x_4 = 100*3.26/16.37
x_4_sem =  1.919/2.211
x_4_sem = 100*np.sqrt((1.919/3.26)**2+(2.211/16.37)**2)/16.37
# No Underreliance

x_6 = 100*5/20.70 
x_6_sem =  1.214/2.173
x_6_sem = 100*np.sqrt((1.214/5)**2+(2.173/20.70)**2)/20.70

# XAI = True

# Reliance

x_0 = 100*8.85/26.88
x_0_sem =    2.83/2.488
x_0_sem = 100*np.sqrt((2.83/8.85)**2+(2.488/26.88)**2)/26.88

# Overreliance

x_3 = 100*3.80/16.20
x_3_sem = 2.905/6.902
x_3_sem = 100*np.sqrt((2.905/3.80)**2+(6.902/16.20)**2)/16.20

# Underreliance

x_5 = 100*10.88/36.50 
x_5_sem = 5.390/4.634
x_5_sem = 100*np.sqrt((5.390/10.88)**2+(4.634/36.50)**2)/36.50


# No Underreliance

x_7 = 100*9.72/28.72
x_7_sem = 3.267/2.560
x_7_sem = 100*np.sqrt((3.267/9.72)**2+(2.560/28.72)**2)/28.72



positions = [1.5, 9.5]
labels = ['Without XAI', 'With XAI']

y_index = [0.5, 8.5]
y_index_2 = [1, 9]
y_index_3 = [1.5, 9.5]
y_index_4 = [2, 10]

plt.figure(figsize=(10, 6))

# Reliance in XAI = False + True
plt.errorbar(y_index, [x_1, x_0],\
              [x_1_sem, x_0_sem], \
             color='black', marker = 'o', markeredgecolor = 'black', markerfacecolor = 'white', ls = 'none', capsize=5, capthick=1, ecolor='black', label = 'Reliance')

# Overreliance in XAI = True and False
plt.errorbar(y_index_2, [x_2, x_3],\
              [x_2_sem, x_3_sem], \
             markeredgecolor = 'black', color='black', marker = 'o', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Overreliance')

# Underreliance in XAI = True and False
plt.errorbar(y_index_3, [x_4, x_5],\
              [x_4_sem, x_5_sem], \
             markeredgecolor = 'black', color='black', markerfacecolor = 'white', marker='s', ls='none', capsize=5, capthick=1, ecolor='black', label = 'Underreliance')

# No Underreliance in XAI = True and False
# plt.errorbar(y_index_4, [x_6, x_7],\
#               [x_6_sem, x_7_sem], \
#              markeredgecolor = 'black', color='black', marker = 'v', ls='none', capsize=5, capthick=1, ecolor='black', label = 'No Underreliance')


plt.legend()
plt.ylabel('Elmo Fixation Count')
plt.xlabel('Presence of XAI')
plt.xticks(positions, labels)
# plt.savefig('reliance_images/means_plot_reliance_groups_probability_fixation.png', dpi = 1600, bbox_inches='tight')
plt.savefig('reliance_images/means_plot_reliance_groups_elmo_fixation_count.pdf', dpi = 600, bbox_inches='tight')
plt.show()
# Out:
# 2.963821068374702
